# %%
pip install mediapipe opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.6/35.6 MB 26.5 MB/s eta 0:00:00
# ...

# %%
https://drive.google.com/drive/folders/1LxdpSeaWqXALTDRErjaCi3FXmFFpeg_q?usp=sharing

# %%
# !gdown --id 1kBWr1NFD5P9FMHxTmD5SteFnMj3xEAaO
# !gdown --id 1FU2PdOIHsgx84hzupcmtH1T6aWb_YcQo
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1kBWr1NFD5P9FMHxTmD5SteFnMj3xEAaO
# From (redirected): https://drive.google.com/uc?id=1kBWr1NFD5P9FMHxTmD5SteFnMj3xEAaO&confirm=t&uuid=cfa6ba05-d73a-4c94-8c12-920f7d319cec
# To: /content/fingerslap and palm individual-20241205T031323Z-001.zip
# 100% 2.14G/2.14G [00:39<00:00, 53.8MB/s]
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1FU2PdOIHsgx84hzupcmtH1T6aWb_YcQo
# ...

# %%
# !unzip '/content/fingerslap and palm individual-20241205T031323Z-001.zip'
# !unzip '/content/fingerslap and palm individual-20241205T031323Z-002.zip'

# %%
# !gdown --id 1c8zkglRxp_VyOeO81-_vvyeLk-zlMv4c
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1c8zkglRxp_VyOeO81-_vvyeLk-zlMv4c
# To: /content/Image_finger.zip
# 100% 22.7M/22.7M [00:00<00:00, 38.4MB/s]

# %%
# !unzip /content/Image_finger.zip

# %%
import cv2
import mediapipe as mp
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
# import cv2
# import mediapipe as mp
# import os
# import numpy as np
# import matplotlib.pyplot as plt
# # Initialize MediaPipe Hands.
# mp_hands = mp.solutions.hands
# hands = mp_hands.Hands(static_image_mode=True, max_num_hands=2, min_detection_confidence=0.5)
# mp_drawing = mp.solutions.drawing_utils

# def crop_fingertip(image, x, y, width=600, height=600):
#     """Crop a region around the given x, y coordinates."""
#     h, w, _ = image.shape
#     x1, y1 = max(0, x - width // 2), max(0, y - height // 2)
#     x2, y2 = min(w, x + width // 2), min(h, y + height // 2)
#     return image[y1:y2, x1:x2]

# def process_images_in_folder(folder_path, save_folder_path):
#     # Iterate through each image in the folder
#     for filename in os.listdir(folder_path):
#         if filename.endswith(('.jpg', '.jpeg', '.png','.JPG')):
#             img_path = os.path.join(folder_path, filename)
#             image = cv2.imread(img_path)
#             if image is None:
#                 print(f"Could not read image {img_path}")
#                 continue

#             image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#             result = hands.process(image_rgb)

#             if result.multi_hand_landmarks:
#                 for hand_landmarks in result.multi_hand_landmarks:
#                     fingertip_indices = [4, 8, 12, 16, 20]
#                     for idx in fingertip_indices:
#                         x = int(hand_landmarks.landmark[idx].x * image.shape[1])
#                         y = int(hand_landmarks.landmark[idx].y * image.shape[0])
#                         cropped_fingertip = crop_fingertip(image, x, y)
#                         fingertip_save_path = os.path.join(save_folder_path, f'{filename.split(".")[0]}_tip{int(idx/4)}.png')
#                         cv2.imwrite(fingertip_save_path, cropped_fingertip)

# root_directory = r'/content/fingerslap and palm individual'
# save_directory = '/content/output1'

# for subject in sorted(os.listdir(root_directory))[1:]:
#     subject_path = os.path.join(root_directory, subject)
#     if os.path.isdir(subject_path):
#         right_hand_folder = os.path.join(subject_path, 'right hand')
#         left_hand_folder = os.path.join(subject_path, 'left hand')
#         save_right_hand_folder = os.path.join(save_directory, subject, 'right hand')
#         save_left_hand_folder = os.path.join(save_directory, subject, 'left hand')
#         os.makedirs(save_right_hand_folder, exist_ok=True)
#         os.makedirs(save_left_hand_folder, exist_ok=True)

#         process_images_in_folder(right_hand_folder, save_right_hand_folder)
#         process_images_in_folder(left_hand_folder, save_left_hand_folder)

# %%
# subject_path
# Out:
# '/content/fingerslap and palm individual/p9'

# %%
import cv2
import mediapipe as mp
import os
import numpy as np
import matplotlib.pyplot as plt
# Initialize MediaPipe Hands.
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(static_image_mode=True, max_num_hands=2, min_detection_confidence=0.25)
mp_drawing = mp.solutions.drawing_utils

def crop_fingertip(image, x, y, width=700, height=700):
    """Crop a region around the given x, y coordinates."""
    h, w, _ = image.shape
    x1, y1 = max(0, x - width // 2), max(0, y - height // 2)
    x2, y2 = min(w, x + width // 2), min(h, y + height // 2)
    return image[y1:y2, x1:x2]

def process_images_in_folder(folder_path, save_folder_path):
    # Iterate through each image in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith(('.jpg', '.jpeg', '.png','.JPG')):
            img_path = os.path.join(folder_path, filename)
            image = cv2.imread(img_path)
            if image is None:
                print(f"Could not read image {img_path}")
                continue

            image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            result = hands.process(image_rgb)

            if result.multi_hand_landmarks:
                for hand_landmarks in result.multi_hand_landmarks:
                    fingertip_indices = [4, 8, 12, 16, 20]
                    for idx in fingertip_indices:
                        x = int(hand_landmarks.landmark[idx].x * image.shape[1])
                        y = int(hand_landmarks.landmark[idx].y * image.shape[0])
                        cropped_fingertip = crop_fingertip(image, x, y)

                        fingertip_save_path = os.path.join(save_folder_path, f'{filename.split(".")[0]}_tip{int(idx/4)}.png')
                        cv2.imwrite(fingertip_save_path, cropped_fingertip)

                        # return cropped_fingertip

root_directory = r'/content/fingerslap and palm individual'
save_directory = '/content/output4'

for subject in sorted(os.listdir(root_directory))[1:]:
    subject_path = os.path.join(root_directory, subject)
    if os.path.isdir(subject_path):
        right_hand_folder = os.path.join(subject_path, 'right hand')
        left_hand_folder = os.path.join(subject_path, 'left hand')
        save_right_hand_folder = os.path.join(save_directory, subject, 'right hand')
        save_left_hand_folder = os.path.join(save_directory, subject, 'left hand')
        os.makedirs(save_right_hand_folder, exist_ok=True)
        os.makedirs(save_left_hand_folder, exist_ok=True)

        process_images_in_folder(right_hand_folder, save_right_hand_folder)
        process_images_in_folder(left_hand_folder, save_left_hand_folder)

# %%
import cv2
import mediapipe as mp
import os
import numpy as np
import matplotlib.pyplot as plt
# Initialize MediaPipe Hands.
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(static_image_mode=True, max_num_hands=2, min_detection_confidence=0.25)
mp_drawing = mp.solutions.drawing_utils

def crop_fingertip(image, x, y, width=450, height=450):
    """Crop a region around the given x, y coordinates."""
    h, w, _ = image.shape
    x1, y1 = max(0, x - width // 2), max(0, y - height // 2)
    x2, y2 = min(w, x + width // 2), min(h, y + height // 2)
    return image[y1:y2, x1:x2]

def process_images_in_folder(folder_path, save_folder_path):
    # Iterate through each image in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith(('.jpg', '.jpeg', '.png','.JPG')):
            img_path = os.path.join(folder_path, filename)
            image = cv2.imread(img_path)
            if image is None:
                print(f"Could not read image {img_path}")
                continue

            image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            result = hands.process(image_rgb)

            if result.multi_hand_landmarks:
                for hand_landmarks in result.multi_hand_landmarks:
                    fingertip_indices = [4, 8, 12, 16, 20]
                    for idx in fingertip_indices:
                        x = int(hand_landmarks.landmark[idx].x * image.shape[1])
                        y = int(hand_landmarks.landmark[idx].y * image.shape[0])
                        cropped_fingertip = crop_fingertip(image, x, y)

                        fingertip_save_path = os.path.join(save_folder_path, f'{filename.split(".")[0]}_tip{int(idx/4)}.png')
                        cv2.imwrite(fingertip_save_path, cropped_fingertip)

                        # return cropped_fingertip

root_directory = r'/content/Image_finger'
save_directory = '/content/output1'

for subject in sorted(os.listdir(root_directory))[1:]:
    subject_path = os.path.join(root_directory, subject)
    if os.path.isdir(subject_path):
        right_hand_folder = os.path.join(subject_path, 'Right')
        left_hand_folder = os.path.join(subject_path, 'Left')
        save_right_hand_folder = os.path.join(save_directory, subject, 'Right')
        save_left_hand_folder = os.path.join(save_directory, subject, 'Left')
        os.makedirs(save_right_hand_folder, exist_ok=True)
        os.makedirs(save_left_hand_folder, exist_ok=True)

        process_images_in_folder(right_hand_folder, save_right_hand_folder)
        process_images_in_folder(left_hand_folder, save_left_hand_folder)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the input fingerprint image
image_path = "/content/output1/P1/Left/p1_r1_tip2.png"  # Replace with the path to your fingerprint image
raw_image = cv2.imread(image_path)

# Convert to grayscale
gray_image = cv2.cvtColor(raw_image, cv2.COLOR_BGR2GRAY)

# Apply Adaptive Mean Thresholding
amt_image = cv2.adaptiveThreshold(
    gray_image,  # Input grayscale image
    255,         # Maximum value to use with THRESH_BINARY
    cv2.ADAPTIVE_THRESH_MEAN_C,  # Adaptive mean thresholding
    cv2.THRESH_BINARY,  # Binary thresholding
    11,          # Block size (size of the neighborhood used to calculate the threshold)
    2            # Constant subtracted from the mean
)

# Save the Ridge-Valley Map image
output_path = "/content/ridge_valley_map.png"  # Replace with your desired output path
cv2.imwrite(output_path, amt_image)
print(f"Ridge-Valley Map saved at: {output_path}")

# Display the results
plt.figure(figsize=(10, 5))

plt.subplot(1, 3, 1)
plt.title("Raw Image")
plt.imshow(cv2.cvtColor(raw_image, cv2.COLOR_BGR2RGB))  # Convert to RGB for matplotlib
plt.axis('off')

plt.subplot(1, 3, 2)
plt.title("Grayscale Image")
plt.imshow(gray_image, cmap='gray')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.title("Ridge-Valley Map (AMT)")
plt.imshow(amt_image, cmap='gray')
plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Ridge-Valley Map saved at: /content/ridge_valley_map.png

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.listdir(root_directory)
# Out:
# ['.DS_Store', 'P1', 'P2']

# %%
plt.imshow(gray_image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-9a64e9af1556> in <cell line: 1>()
# ----> 1 plt.imshow(gray_image)
#
# NameError: name 'gray_image' is not defined

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread('/content/output/P1/Left/p1_r1_tip2.png')

# Convert the image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply CLAHE (Contrast Limited Adaptive Histogram Equalization)
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
clahe_image = clahe.apply(gray_image)

# Threshold the image to create a binary mask
_, mask = cv2.threshold(clahe_image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# Find contours to crop the fingertip
contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Assuming the largest contour corresponds to the fingertip
contour = max(contours, key=cv2.contourArea)

# Get the bounding box of the contour
x, y, w, h = cv2.boundingRect(contour)

# Crop the fingertip from the original image
cropped_fingertip = image[y:y+h, x:x+w]

# Create a white background
white_background = np.ones_like(cropped_fingertip) * 255

# Copy the cropped fingertip onto the white background
cropped_fingertip_on_white = white_background.copy()
cropped_fingertip_on_white[mask[y:y+h, x:x+w] == 255] = cropped_fingertip[mask[y:y+h, x:x+w] == 255]

# Plot the original grayscale image and the processed image side by side
plt.figure(figsize=(10, 5))

# Original Grayscale Image
plt.subplot(1, 2, 1)
plt.title('Gray Image')
plt.imshow(gray_image, cmap='gray')
plt.axis('off')

# Processed Fingertip Image
plt.subplot(1, 2, 2)
plt.title('Processed Fingertip')
# plt.imshow(cv2.cvtColor(cropped_fingertip_on_white, cv2.COLOR_BGR2RGB))
plt.imshow(cv2.cvtColor(cropped_fingertip_on_white, cv2.COLOR_BGR2GRAY), cmap='gray')
plt.axis('off')

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread('/content/output/P1/Left/p1_r1_tip4.png')
# Rotate the original image
image = cv2.rotate(image, cv2.ROTATE_90_CLOCKWISE)
# Resize the rotated image to a fixed size
desired_size = (300, 300)
image= cv2.resize(image, desired_size)

# Convert the image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply CLAHE (Contrast Limited Adaptive Histogram Equalization)
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(24,24))
clahe_image = clahe.apply(gray_image)

# Threshold the image to create a binary mask
_, mask = cv2.threshold(clahe_image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# Apply morphological operations to remove small black spots
kernel = np.ones((7,7), np.uint8)
clean_mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)

# Find contours to crop the fingertip
contours, _ = cv2.findContours(clean_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Assuming the largest contour corresponds to the fingertip
contour = max(contours, key=cv2.contourArea)

# Get the bounding box of the contour
x, y, w, h = cv2.boundingRect(contour)

# Crop the fingertip from the original image
cropped_fingertip = image[y:y+h, x:x+w]

# Create a white background
white_background = np.ones_like(cropped_fingertip) * 255

# Copy the cropped fingertip onto the white background
cropped_fingertip_on_white = white_background.copy()
cropped_fingertip_on_white[clean_mask[y:y+h, x:x+w] == 255] = cropped_fingertip[clean_mask[y:y+h, x:x+w] == 255]

cropped_fingertip_on_white = cv2.resize(cropped_fingertip_on_white, desired_size)

# # Plot the original grayscale image and the processed image side by side
# plt.figure(figsize=(10, 5))

# # Original Grayscale Image
# plt.subplot(1, 2, 1)
# plt.title('Gray Image')
# plt.imshow(gray_image, cmap='gray')
# plt.axis('off')

# # Processed Fingertip Image
# plt.subplot(1, 2, 2)
# plt.title('Processed Fingertip')
# plt.imshow(cv2.cvtColor(cropped_fingertip_on_white, cv2.COLOR_BGR2GRAY), cmap='gray')
# plt.axis('off')

# plt.show()


# Plot the images
plt.figure(figsize=(10, 10))

# Original Image
plt.subplot(2, 2, 1)
plt.title('Original Image')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')

# Grayscale Image
plt.subplot(2, 2, 2)
plt.title('Grayscale Image')
plt.imshow(gray_image, cmap='gray')
plt.axis('off')

# CLAHE Image
plt.subplot(2, 2, 3)
plt.title('CLAHE Image')
plt.imshow(clahe_image, cmap='gray')
plt.axis('off')

# Cropped and Rotated Image
plt.subplot(2, 2, 4)
plt.title('Cropped and Rotated Fingertip')
plt.imshow(cv2.cvtColor(cropped_fingertip_on_white, cv2.COLOR_BGR2GRAY), cmap='gray')
plt.axis('off')

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread('/content/output/P1/Left/p1_r1_tip4.png')
# Rotate the original image
image_rotated = cv2.rotate(image, cv2.ROTATE_90_CLOCKWISE)

# Resize the rotated image to a fixed size
desired_size = (300, 300)
image_resized = cv2.resize(image_rotated, desired_size)


# Convert the image to grayscale
gray_image = cv2.cvtColor(image_resized, cv2.COLOR_BGR2GRAY)

# Apply CLAHE (Contrast Limited Adaptive Histogram Equalization)
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(32,32))
clahe_image = clahe.apply(gray_image)
# clahe_image = cv.fastNlMeansDenoising(clahe_image, h=50, templateWindowSize=21, searchWindowSize=21)


# Threshold the image to create a binary mask
_, mask = cv2.threshold(clahe_image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# Find contours to crop the fingertip
contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Assuming the largest contour corresponds to the fingertip
contour = max(contours, key=cv2.contourArea)


# img = cv.imread(abspath(sourceImage), cv.IMREAD_GRAYSCALE)
# img = cv.createCLAHE(tileGridSize=(32,32)).apply(gray_image)
# img = cv.fastNlMeansDenoising(img, h=50, templateWindowSize=21, searchWindowSize=21)
# img = 255 - img

# mask = cv.imread(join(args.masks, basename(sourceImage)), cv.IMREAD_GRAYSCALE)

# img[mask == 0] = 255



# Get the bounding box of the contour
x, y, w, h = cv2.boundingRect(contour)

# Crop the fingertip from the original image
cropped_fingertip = gray_image[y:y+h, x:x+w]

# Resize cropped fingertip image to the same size as others
cropped_fingertip_resized = cv2.resize(cropped_fingertip, desired_size)


# Plot the images
plt.figure(figsize=(10, 10))

# Original Image
plt.subplot(2, 2, 1)
plt.title('Original Image')
plt.imshow(cv2.cvtColor(image_resized, cv2.COLOR_BGR2RGB))
plt.axis('off')

# Grayscale Image
plt.subplot(2, 2, 2)
plt.title('Grayscale Image')
plt.imshow(gray_image, cmap='gray')
plt.axis('off')

# CLAHE Image
plt.subplot(2, 2, 3)
plt.title('CLAHE Image')
plt.imshow(clahe_image, cmap='gray')
plt.axis('off')

# Cropped and Rotated Image
plt.subplot(2, 2, 4)
plt.title('Cropped and Rotated Fingertip')
plt.imshow(cropped_fingertip_resized, cmap='gray')
plt.axis('off')

plt.show()

# %%
import argparse
import os
from os.path import abspath, basename, join
from pathlib import Path
from threading import Thread


import cv2 as cv
import numpy as np
from tqdm import tqdm

destination = 'out'

def find_hull (image_path, resize_resolution):
    img = cv.imread(abspath(image_path), cv.IMREAD_GRAYSCALE)

    _, width = img.shape

    ratio = resize_resolution/width

    img = cv.resize(img, None, fx=ratio, fy=ratio)
    original = cv.resize(cv.imread(abspath(image_path)), None, fx=ratio, fy=ratio)

    blurred = cv.medianBlur(original, 9)

    canny = cv.Canny(blurred, 50, 100)

    canny = cv.dilate(canny, np.ones((3,3), np.uint8), iterations=1)

    _, canny = cv.threshold(canny, 25, 255, cv.THRESH_BINARY)

    canny = cv.bitwise_not(canny)

    mask = np.zeros(img.shape, np.uint8)
    mask[img < 25] = 255

    clahe = cv.createCLAHE(tileGridSize=(4,4))

    img = clahe.apply(img)

    _, img = cv.threshold(img, 64, 255, cv.THRESH_BINARY)

    img = cv.bitwise_and(img, canny)

# %%
source_images_batch=sorted(list(Path('/content/output/P1/Left').glob('*.png')))

# def main (source_images_batch):

for source_image in tqdm(source_images_batch):

    contours = []

    for i in [128, 256, 512]:
        contours.append(find_hull(source_image, i))

    mask = find_contour_intersection(source_image, contours)
    mask = cv.erode(mask, np.ones((3,3), np.uint8), iterations=20)

    cv.imwrite(join(destination, basename(source_image)), mask)

# %%
# Threshold the image to create a binary mask
_, mask = cv2.threshold(clahe_image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# Find contours to crop the fingertip
contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Assuming the largest contour corresponds to the fingertip
contour = max(contours, key=cv2.contourArea)

# %%
if __name__ == '__main__':

    parser = argparse.ArgumentParser()
    parser.add_argument('source')
    parser.add_argument('destination')
    args = parser.parse_args()

    if not os.path.isdir(args.destination):
        os.mkdir(args.destination)

    source_images = sorted(list(Path(args.source).glob('*.png')))

    for i in range(20):
        source_images_batch = source_images[i::20]
        thread = Thread(target=main, args=(source_images_batch,))
        thread.start()

# %%
import argparse
import os
from os.path import abspath, basename, join
from pathlib import Path
from threading import Thread

import cv2 as cv
from tqdm import tqdm


def main (sourceImagesBatch):

    for sourceImage in tqdm(sourceImagesBatch):

        img = cv.imread(abspath(sourceImage), cv.IMREAD_GRAYSCALE)
        img = cv.createCLAHE(tileGridSize=(32,32)).apply(img)
        img = cv.fastNlMeansDenoising(img, h=50, templateWindowSize=21, searchWindowSize=21)
        img = 255 - img

        mask = cv.imread(join(args.masks, basename(sourceImage)), cv.IMREAD_GRAYSCALE)

        img[mask == 0] = 255

        cv.imwrite(join(args.destination, basename(sourceImage)), img)


if __name__ == '__main__':

    parser = argparse.ArgumentParser()
    parser.add_argument('images')
    parser.add_argument('masks')
    parser.add_argument('destination')
    args = parser.parse_args()

    if not os.path.isdir(args.destination):
        os.mkdir(args.destination)

    sourceImages = sorted(list(Path(args.images).glob('*.png')))

    for i in range(20):
        sourceImagesBatch = sourceImages[i::20]
        thread = Thread(target=main, args=(sourceImagesBatch,))
        thread.start()
# Out:
# usage: colab_kernel_launcher.py [-h] images masks destination
# colab_kernel_launcher.py: error: the following arguments are required: masks, destination
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py:3561: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
img = cv.imread(abspath(sourceImage), cv.IMREAD_GRAYSCALE)
img = cv.createCLAHE(tileGridSize=(32,32)).apply(img)
img = cv.fastNlMeansDenoising(img, h=50, templateWindowSize=21, searchWindowSize=21)
img = 255 - img

mask = cv.imread(join(args.masks, basename(sourceImage)), cv.IMREAD_GRAYSCALE)

img[mask == 0] = 255

# %%
pip install fingerprint-feature-extractor
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fingerprint-feature-extractor: filename=fingerprint_feature_extractor-0.0.10-py3-none-any.whl size=4828 sha256=cd97c74bdcebec1846b223a0becf0bc4bbea6b0c647b135eea84d9344d6c00ce
#   Stored in directory: /root/.cache/pip/wheels/ad/fc/d9/ce6a90506bdff6f93044b68e229602e5b9dece43e0b9fa1d6f
# Successfully built fingerprint-feature-extractor
# ...

# %%
import fingerprint_feature_extractor
# img = cv2.imread('image_path', 0)				# read the input image --> You can enhance the fingerprint image using the "fingerprint_enhancer" library
from google.colab.patches import cv2_imshow
img1=cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
FeaturesTerminations, FeaturesBifurcations = fingerprint_feature_extractor.extract_minutiae_features(img1, spuriousMinutiaeThresh=10, invertImage=False, showResult=True, saveResult=True)

# %%
FeaturesBifurcations

# %%
# a=(cv2.cvtColor(cropped_fingertip_on_white, cv2.COLOR_BGR2GRAY), cmap='gray')
plt.imshow(cv2.cvtColor(cropped_fingertip_on_white, cv2.COLOR_BGR2GRAY), cmap='gray')

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load your grayscale fingerprint image (assuming 'cropped_fingertip_on_white' is already processed)
gray_fingerprint = cv2.cvtColor(cropped_fingertip_on_white, cv2.COLOR_BGR2GRAY)

# Apply Gaussian Blur to reduce noise
blurred_fingerprint = cv2.GaussianBlur(gray_fingerprint, (5, 5), 0)

# Binarize the image using adaptive thresholding
binary_fingerprint = cv2.adaptiveThreshold(
    blurred_fingerprint,
    255,
    cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
    cv2.THRESH_BINARY_INV,
    11,
    2
)

# Apply morphological thinning to reduce ridges to a single pixel width
thinned_fingerprint = cv2.ximgproc.thinning(binary_fingerprint, thinningType=cv2.ximgproc.THINNING_ZHANGSUEN)

# Minutiae extraction: ridge endings and bifurcations
def minutiae_extraction(thinned_image):
    minutiae_endings = []
    minutiae_bifurcations = []

    # Define the neighborhood for checking 3x3 region
    for i in range(1, thinned_image.shape[0] - 1):
        for j in range(1, thinned_image.shape[1] - 1):
            if thinned_image[i, j] == 255:  # Ridge pixel
                # Extract 3x3 neighborhood
                neighborhood = thinned_image[i-1:i+2, j-1:j+2]

                # Count the number of white pixels (sum of 1s) in the neighborhood
                count = np.sum(neighborhood == 255)

                if count == 2:  # Ridge ending (one entry and one exit point)
                    minutiae_endings.append((j, i))
                elif count == 4:  # Bifurcation (more than two exits)
                    minutiae_bifurcations.append((j, i))

    return minutiae_endings, minutiae_bifurcations

# Extract minutiae points
endings, bifurcations = minutiae_extraction(thinned_fingerprint)

# Plot the thinned fingerprint and minutiae points
plt.figure(figsize=(10, 10))

# Thinned Fingerprint Image
plt.subplot(1, 1, 1)
plt.title('Thinned Fingerprint with Minutiae')
plt.imshow(gray_fingerprint, cmap='gray')
plt.axis('off')

# Plotting ridge endings in red
for (x, y) in endings:
    plt.scatter(x, y, color='red', s=10)

# Plotting bifurcations in blue
for (x, y) in bifurcations:
    plt.scatter(x, y, color='blue', s=10)

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load your grayscale fingerprint image (assuming 'cropped_fingertip_on_white' is already processed)
gray_fingerprint = cv2.cvtColor(cropped_fingertip_on_white, cv2.COLOR_BGR2GRAY)

# Apply Gaussian Blur to reduce high-frequency noise
blurred_fingerprint = cv2.GaussianBlur(gray_fingerprint, (3, 3), 0)

# Apply Median Filtering to reduce salt-and-pepper noise
median_filtered = cv2.medianBlur(blurred_fingerprint, 3)

# Apply Bilateral Filtering to further reduce noise while preserving edges
# Reduced the parameters to avoid excessive blurring
bilateral_filtered = cv2.bilateralFilter(median_filtered, d=5, sigmaColor=50, sigmaSpace=50)

# Binarize the image using adaptive thresholding
binary_fingerprint = cv2.adaptiveThreshold(
    bilateral_filtered,
    255,
    cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
    cv2.THRESH_BINARY_INV,
    11,
    2
)

# Apply Morphological Closing with a smaller kernel size
kernel = np.ones((2,2), np.uint8)
closed_fingerprint = cv2.morphologyEx(binary_fingerprint, cv2.MORPH_CLOSE, kernel)

# Apply morphological thinning to reduce ridges to a single pixel width
thinned_fingerprint = cv2.ximgproc.thinning(closed_fingerprint, thinningType=cv2.ximgproc.THINNING_ZHANGSUEN)

# Minutiae extraction: ridge endings and bifurcations
def minutiae_extraction(thinned_image):
    minutiae_endings = []
    minutiae_bifurcations = []

    # Define the neighborhood for checking 3x3 region
    for i in range(1, thinned_image.shape[0] - 1):
        for j in range(1, thinned_image.shape[1] - 1):
            if thinned_image[i, j] == 255:  # Ridge pixel
                # Extract 3x3 neighborhood
                neighborhood = thinned_image[i-1:i+2, j-1:j+2]

                # Count the number of white pixels (sum of 1s) in the neighborhood
                count = np.sum(neighborhood == 255)

                if count == 2:  # Ridge ending (one entry and one exit point)
                    minutiae_endings.append((j, i))
                elif count == 4:  # Bifurcation (more than two exits)
                    minutiae_bifurcations.append((j, i))

    return minutiae_endings, minutiae_bifurcations

# Extract minutiae points
endings, bifurcations = minutiae_extraction(thinned_fingerprint)

# Plot the thinned fingerprint and minutiae points
plt.figure(figsize=(10, 10))

# Thinned Fingerprint Image
plt.subplot(1, 1, 1)
plt.title('Thinned Fingerprint with Minutiae')
plt.imshow(gray_fingerprint, cmap='gray')
plt.axis('off')

# Plotting ridge endings in red
for (x, y) in endings:
    plt.scatter(x, y, color='red', s=10)

# Plotting bifurcations in blue
for (x, y) in bifurcations:
    plt.scatter(x, y, color='blue', s=10)

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load your grayscale fingerprint image (assuming 'cropped_fingertip_on_white' is already processed)
gray_fingerprint = cv2.cvtColor(cropped_fingertip_on_white, cv2.COLOR_BGR2GRAY)
# gray_fingerprint=cropped_fingertip_on_white
# Apply Gaussian Blur to reduce high-frequency noise
blurred_fingerprint = cv2.GaussianBlur(gray_fingerprint, (3, 3), 0)

# Apply Median Filtering to reduce salt-and-pepper noise
median_filtered = cv2.medianBlur(blurred_fingerprint, 3)

# Apply Bilateral Filtering to further reduce noise while preserving edges
bilateral_filtered = cv2.bilateralFilter(median_filtered, d=5, sigmaColor=50, sigmaSpace=50)

# Binarize the image using adaptive thresholding
binary_fingerprint = cv2.adaptiveThreshold(
    bilateral_filtered,
    255,
    cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
    cv2.THRESH_BINARY_INV,
    11,
    2
)

# Apply Morphological Closing with a smaller kernel size
kernel = np.ones((1,1), np.uint8)
closed_fingerprint = cv2.morphologyEx(binary_fingerprint, cv2.MORPH_CLOSE, kernel)

# Apply morphological thinning to reduce ridges to a single pixel width
# thinned_fingerprint = cv2.ximgproc.thinning(closed_fingerprint, thinningType=cv2.ximgproc.THINNING_ZHANGSUEN)

thinned_fingerprint=closed_fingerprint

# Minutiae extraction: ridge endings and bifurcations
def minutiae_extraction(thinned_image):
    minutiae_endings = []
    minutiae_bifurcations = []

    # Define the neighborhood for checking 3x3 region
    for i in range(1, thinned_image.shape[0] - 1):
        for j in range(1, thinned_image.shape[1] - 1):
            if thinned_image[i, j] == 255:  # Ridge pixel
                # Extract 3x3 neighborhood
                neighborhood = thinned_image[i-1:i+2, j-1:j+2]

                # Count the number of white pixels (sum of 1s) in the neighborhood
                count = np.sum(neighborhood == 255)

                if count == 2:  # Ridge ending (one entry and one exit point)
                    minutiae_endings.append((j, i))
                elif count == 4:  # Bifurcation (more than two exits)
                    minutiae_bifurcations.append((j, i))

    return minutiae_endings, minutiae_bifurcations

# Extract minutiae points
endings, bifurcations = minutiae_extraction(thinned_fingerprint)

# Convert the thinned fingerprint to BGR so we can draw colored rectangles
fingerprint_with_boxes = cv2.cvtColor(gray_fingerprint, cv2.COLOR_GRAY2BGR)

# Plotting ridge endings in red
# for (x, y) in endings:
#     cv2.circle(fingerprint_with_boxes, (x, y), 1, (0, 0, 255), -1)  # Red circle

box_size = 4  # Size of the box around bifurcation points
for (x, y) in endings:
    top_left = (x - box_size // 2, y - box_size // 2)
    bottom_right = (x + box_size // 2, y + box_size // 2)
    cv2.rectangle(fingerprint_with_boxes, top_left, bottom_right, ( 0, 0,255), 1)  # Blue rectangle

# Plotting bifurcations as small rectangles in blue
# box_size = 5  # Size of the box around bifurcation points
for (x, y) in bifurcations:
    top_left = (x - box_size // 2, y - box_size // 2)
    bottom_right = (x + box_size // 2, y + box_size // 2)
    cv2.rectangle(fingerprint_with_boxes, top_left, bottom_right, ( 0, 0,255), 1)  # Blue rectangle

# Plot the thinned fingerprint with minutiae points and rectangles
plt.figure(figsize=(10, 10))
plt.title('Thinned Fingerprint with Minutiae and Bifurcation Boxes')
plt.imshow(cv2.cvtColor(fingerprint_with_boxes, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load your grayscale fingerprint image (assuming 'cropped_fingertip_on_white' is already processed)
gray_fingerprint = cv2.cvtColor(cropped_fingertip_on_white, cv2.COLOR_BGR2GRAY)
# gray_fingerprint=cropped_fingertip_on_white
# Apply Gaussian Blur to reduce high-frequency noise
blurred_fingerprint = cv2.GaussianBlur(gray_fingerprint, (3, 3), 0)

# Apply Median Filtering to reduce salt-and-pepper noise
median_filtered = cv2.medianBlur(blurred_fingerprint, 3)

# Apply Bilateral Filtering to further reduce noise while preserving edges
bilateral_filtered = cv2.bilateralFilter(median_filtered, d=5, sigmaColor=50, sigmaSpace=50)

# Binarize the image using adaptive thresholding
binary_fingerprint = cv2.adaptiveThreshold(
    bilateral_filtered,
    255,
    cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
    cv2.THRESH_BINARY_INV,
    11,
    2
)

# Apply Morphological Closing with a smaller kernel size
kernel = np.ones((1,1), np.uint8)
closed_fingerprint = cv2.morphologyEx(binary_fingerprint, cv2.MORPH_CLOSE, kernel)

# Apply morphological thinning to reduce ridges to a single pixel width
thinned_fingerprint = cv2.ximgproc.thinning(closed_fingerprint, thinningType=cv2.ximgproc.THINNING_ZHANGSUEN)

# Minutiae extraction: ridge endings and bifurcations
def minutiae_extraction(thinned_image):
    minutiae_endings = []
    minutiae_bifurcations = []

    # Define the neighborhood for checking 3x3 region
    for i in range(1, thinned_image.shape[0] - 1):
        for j in range(1, thinned_image.shape[1] - 1):
            if thinned_image[i, j] == 255:  # Ridge pixel
                # Extract 3x3 neighborhood
                neighborhood = thinned_image[i-1:i+2, j-1:j+2]

                # Count the number of white pixels (sum of 1s) in the neighborhood
                count = np.sum(neighborhood == 255)

                if count == 2:  # Ridge ending (one entry and one exit point)
                    minutiae_endings.append((j, i))
                elif count == 4:  # Bifurcation (more than two exits)
                    minutiae_bifurcations.append((j, i))

    return minutiae_endings, minutiae_bifurcations

# Extract minutiae points
endings, bifurcations = minutiae_extraction(thinned_fingerprint)

# Convert the thinned fingerprint to BGR so we can draw colored rectangles
fingerprint_with_boxes = cv2.cvtColor(gray_fingerprint, cv2.COLOR_GRAY2BGR)

# Plotting ridge endings in red
# for (x, y) in endings:
#     cv2.circle(fingerprint_with_boxes, (x, y), 1, (0, 0, 255), -1)  # Red circle

box_size = 4  # Size of the box around bifurcation points
for (x, y) in endings:
    top_left = (x - box_size // 2, y - box_size // 2)
    bottom_right = (x + box_size // 2, y + box_size // 2)
    cv2.rectangle(fingerprint_with_boxes, top_left, bottom_right, ( 0, 0,255), 1)  # Blue rectangle

# Plotting bifurcations as small rectangles in blue
# box_size = 5  # Size of the box around bifurcation points
for (x, y) in bifurcations:
    top_left = (x - box_size // 2, y - box_size // 2)
    bottom_right = (x + box_size // 2, y + box_size // 2)
    cv2.rectangle(fingerprint_with_boxes, top_left, bottom_right, ( 0, 0,255), 1)  # Blue rectangle

# Plot the thinned fingerprint with minutiae points and rectangles
plt.figure(figsize=(10, 10))
plt.title('Thinned Fingerprint with Minutiae and Bifurcation Boxes')
plt.imshow(cv2.cvtColor(fingerprint_with_boxes, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
pip install fingerprint_enhancer
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fingerprint_enhancer: filename=fingerprint_enhancer-0.0.13-py3-none-any.whl size=8904 sha256=e014f617628a6e516f4639acaf1b2d1909da27d3f61199d0f3771ff799bad85f
#   Stored in directory: /root/.cache/pip/wheels/91/ae/50/978165dd230375061475f4594febfe8a42869c4cc5374f9740
# Successfully built fingerprint_enhancer
# ...

# %%
img=cropped_fingertip_on_white

# %%
import fingerprint_enhancer								# Load the library
import cv2
from google.colab.patches import cv2_imshow
# img = cv2.imread('image_path', 0)						# read input image
out = fingerprint_enhancer.enhance_Fingerprint(img)		# enhance the fingerprint image
cv2_imshow( out);						# display the result
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-86efb9245499> in <cell line: 5>()
#       3 from google.colab.patches import cv2_imshow
#       4 # img = cv2.imread('image_path', 0)                                             # read input image
# ----> 5 out = fingerprint_enhancer.enhance_Fingerprint(img)             # enhance the fingerprint image
#       6 cv2_imshow( out);                                               # display the result
#       7 cv2.waitKey(0)
#
# /usr/local/lib/python3.10/dist-packages/fingerprint_enhancer/__init__.py in enhance_Fingerprint(img, resize, ridge_segment_blksze, ridge_segment_thresh, gradient_sigma, block_sigma, orient_smooth_sigma, ridge_freq_blksze, ridge_freq_windsze, min_wave_length, max_wave_length, kx, ky, angleInc, ridge_filter_thresh)
# ...

# %%
image.dtype
# Out:
# dtype('uint8')

# %%
plt.imshow(img)

# %%
import cv2
import numpy as np
import skimage.morphology
from skimage.morphology import convex_hull_image, erosion
from skimage.morphology import square
import math

class MinutiaeFeature(object):
    def __init__(self, locX, locY, Orientation, Type):
        self.locX = locX
        self.locY = locY
        self.Orientation = Orientation
        self.Type = Type

class FingerprintFeatureExtractor1(object):
    def __init__(self):
        self._mask = []
        self._skel = []
        self.minutiaeTerm = []
        self.minutiaeBif = []
        self._spuriousMinutiaeThresh = 10

    def setSpuriousMinutiaeThresh(self, spuriousMinutiaeThresh):
        self._spuriousMinutiaeThresh = spuriousMinutiaeThresh

    def __skeletonize(self, img):
        img = np.uint8(img > 128)
        self._skel = skimage.morphology.skeletonize(img)
        self._skel = np.uint8(self._skel) * 255
        self._mask = img * 255

    def __computeAngle(self, block, minutiaeType):
        angle = []
        (blkRows, blkCols) = np.shape(block)
        CenterX, CenterY = (blkRows - 1) / 2, (blkCols - 1) / 2
        if (minutiaeType.lower() == 'termination'):
            sumVal = 0
            for i in range(blkRows):
                for j in range(blkCols):
                    if ((i == 0 or i == blkRows - 1 or j == 0 or j == blkCols - 1) and block[i][j] != 0):
                        angle.append(-math.degrees(math.atan2(i - CenterY, j - CenterX)))
                        sumVal += 1
                        if (sumVal > 1):
                            angle.append(float('nan'))
            return (angle)

        elif (minutiaeType.lower() == 'bifurcation'):
            (blkRows, blkCols) = np.shape(block)
            CenterX, CenterY = (blkRows - 1) / 2, (blkCols - 1) / 2
            angle = []
            sumVal = 0
            for i in range(blkRows):
                for j in range(blkCols):
                    if ((i == 0 or i == blkRows - 1 or j == 0 or j == blkCols - 1) and block[i][j] != 0):
                        angle.append(-math.degrees(math.atan2(i - CenterY, j - CenterX)))
                        sumVal += 1
            if (sumVal != 3):
                angle.append(float('nan'))
            return (angle)

    def __getTerminationBifurcation(self):
        self._skel = self._skel == 255
        (rows, cols) = self._skel.shape
        self.minutiaeTerm = np.zeros(self._skel.shape)
        self.minutiaeBif = np.zeros(self._skel.shape)

        for i in range(1, rows - 1):
            for j in range(1, cols - 1):
                if (self._skel[i][j] == 1):
                    block = self._skel[i - 1:i + 2, j - 1:j + 2]
                    block_val = np.sum(block)
                    if (block_val == 2):
                        self.minutiaeTerm[i, j] = 1
                    elif (block_val == 4):
                        self.minutiaeBif[i, j] = 1

        self._mask = convex_hull_image(self._mask > 0)
        self._mask = erosion(self._mask, square(5))  # Structuing element for mask erosion = square(5)
        self.minutiaeTerm = np.uint8(self._mask) * self.minutiaeTerm

    def __removeSpuriousMinutiae(self, minutiaeList, img):
        img = img * 0
        SpuriousMin = []
        numPoints = len(minutiaeList)
        D = np.zeros((numPoints, numPoints))
        for i in range(1,numPoints):
            for j in range(0, i):
                (X1,Y1) = minutiaeList[i]['centroid']
                (X2,Y2) = minutiaeList[j]['centroid']

                dist = np.sqrt((X2-X1)**2 + (Y2-Y1)**2)
                D[i][j] = dist
                if(dist < self._spuriousMinutiaeThresh):
                    SpuriousMin.append(i)
                    SpuriousMin.append(j)

        SpuriousMin = np.unique(SpuriousMin)
        for i in range(0,numPoints):
            if(not i in SpuriousMin):
                (X,Y) = np.int16(minutiaeList[i]['centroid'])
                img[X,Y] = 1

        img = np.uint8(img)
        return(img)

    def __cleanMinutiae(self, img):
        self.minutiaeTerm = skimage.measure.label(self.minutiaeTerm, connectivity=2)
        RP = skimage.measure.regionprops(self.minutiaeTerm)
        self.minutiaeTerm = self.__removeSpuriousMinutiae(RP, np.uint8(img))

    def __performFeatureExtraction(self):
        FeaturesTerm = []
        self.minutiaeTerm = skimage.measure.label(self.minutiaeTerm, connectivity=2)
        RP = skimage.measure.regionprops(np.uint8(self.minutiaeTerm))

        WindowSize = 2  # --> For Termination, the block size must can be 3x3, or 5x5. Hence the window selected is 1 or 2
        FeaturesTerm = []
        for num, i in enumerate(RP):
            (row, col) = np.int16(np.round(i['Centroid']))
            block = self._skel[row - WindowSize:row + WindowSize + 1, col - WindowSize:col + WindowSize + 1]
            angle = self.__computeAngle(block, 'Termination')
            if(len(angle) == 1):
                FeaturesTerm.append(MinutiaeFeature(row, col, angle, 'Termination'))

        FeaturesBif = []
        self.minutiaeBif = skimage.measure.label(self.minutiaeBif, connectivity=2)
        RP = skimage.measure.regionprops(np.uint8(self.minutiaeBif))
        WindowSize = 1  # --> For Bifurcation, the block size must be 3x3. Hence the window selected is 1
        for i in RP:
            (row, col) = np.int16(np.round(i['Centroid']))
            block = self._skel[row - WindowSize:row + WindowSize + 1, col - WindowSize:col + WindowSize + 1]
            angle = self.__computeAngle(block, 'Bifurcation')
            if(len(angle) == 3):
                FeaturesBif.append(MinutiaeFeature(row, col, angle, 'Bifurcation'))
        return (FeaturesTerm, FeaturesBif)

    def extractMinutiaeFeatures(self, img):
        self.__skeletonize(img)

        self.__getTerminationBifurcation()

        self.__cleanMinutiae(img)

        FeaturesTerm, FeaturesBif = self.__performFeatureExtraction()
        return(FeaturesTerm, FeaturesBif)

    def showResults(self, FeaturesTerm, FeaturesBif):

        (rows, cols) = self._skel.shape
        DispImg = np.zeros((rows, cols, 3), np.uint8)
        DispImg[:, :, 0] = 255*self._skel
        DispImg[:, :, 1] = 255*self._skel
        DispImg[:, :, 2] = 255*self._skel

        for idx, curr_minutiae in enumerate(FeaturesTerm):
            row, col = curr_minutiae.locX, curr_minutiae.locY
            (rr, cc) = skimage.draw.circle_perimeter(row, col, 3)
            skimage.draw.set_color(DispImg, (rr, cc), (0, 0, 255))

        for idx, curr_minutiae in enumerate(FeaturesBif):
            row, col = curr_minutiae.locX, curr_minutiae.locY
            (rr, cc) = skimage.draw.circle_perimeter(row, col, 3)
            skimage.draw.set_color(DispImg, (rr, cc), (255, 0, 0))

        cv2.imshow('output', DispImg)
        cv2.waitKey(0)

    def saveResult(self, FeaturesTerm, FeaturesBif):
        (rows, cols) = self._skel.shape
        DispImg = np.zeros((rows, cols, 3), np.uint8)
        DispImg[:, :, 0] = 255 * self._skel
        DispImg[:, :, 1] = 255 * self._skel
        DispImg[:, :, 2] = 255 * self._skel

        for idx, curr_minutiae in enumerate(FeaturesTerm):
            row, col = curr_minutiae.locX, curr_minutiae.locY
            (rr, cc) = skimage.draw.circle_perimeter(row, col, 3)
            skimage.draw.set_color(DispImg, (rr, cc), (0, 0, 255))

        for idx, curr_minutiae in enumerate(FeaturesBif):
            row, col = curr_minutiae.locX, curr_minutiae.locY
            (rr, cc) = skimage.draw.circle_perimeter(row, col, 3)
            skimage.draw.set_color(DispImg, (rr, cc), (255, 0, 0))
        cv2.imwrite('result.png', DispImg)

def extract_minutiae_features2(img, spuriousMinutiaeThresh=10, invertImage=False, showResult=False, saveResult=False):
    feature_extractor = FingerprintFeatureExtractor()
    feature_extractor.setSpuriousMinutiaeThresh(spuriousMinutiaeThresh)
    if (invertImage):
        img = 255 - img;

    FeaturesTerm, FeaturesBif = feature_extractor.extractMinutiaeFeatures(img)

    if (saveResult):
        feature_extractor.saveResult(FeaturesTerm, FeaturesBif)

    if(showResult):
        feature_extractor.showResults(FeaturesTerm, FeaturesBif)

    return(FeaturesTerm, FeaturesBif)
